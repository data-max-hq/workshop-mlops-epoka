# %%
# Workshop

# %%
## Train the model

# %%
# !cd 1_train
# !python train.py

# %%
# model.pkl available in 2_models

# %%
# Serve the model

# %%
# !cd 3_app
# !python app.py

# %%
# !cd 4_docker
# !docker build -t hello-ml .
# !docker run -it -p 5000:5000 hello-ml
# Out:
# [+] Building 0.0s (0/1)
# [+] Building 0.1s (2/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 988B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8.10           0.0s
# [+] Building 0.3s (2/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 988B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8.10           0.2s
# [+] Building 0.4s (2/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 988B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8.10           0.3s
# [+] Building 0.6s (2/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 988B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8.10           0.5s
# [+] Building 0.7s (2/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 988B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8.10           0.6s
# [+] Building 0.9s (2/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 988B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8.10           0.8s
# [+] Building 1.0s (2/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 988B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8.10           0.9s
# [+] Building 1.2s (2/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 988B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8.10           1.1s
# [+] Building 1.3s (2/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 988B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8.10           1.2s
# [+] Building 1.5s (2/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 988B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8.10           1.4s
# [+] Building 1.6s (2/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 988B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8.10           1.5s
# [+] Building 1.8s (2/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 988B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8.10           1.7s
# [+] Building 1.9s (2/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 988B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8.10           1.8s
# [+] Building 2.1s (2/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 988B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8.10           2.0s
# [+] Building 2.2s (2/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 988B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8.10           2.1s
# [+] Building 2.4s (2/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 988B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8.10           2.3s
# [+] Building 2.5s (2/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 988B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8.10           2.4s
# [+] Building 2.6s (3/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 988B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8.10           2.5s
# [+] Building 2.8s (7/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 988B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8.10           2.5s
#  => [1/7] FROM docker.io/library/python:3.8.10@sha256:f7981c32c931f07d053  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 4.67kB                                        0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] COPY requirements.txt requirements.txt                           0.0s
#  => [4/7] RUN pip install -r requirements.txt                              0.1s
# [+] Building 2.9s (7/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 988B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8.10           2.5s
#  => [1/7] FROM docker.io/library/python:3.8.10@sha256:f7981c32c931f07d053  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 4.67kB                                        0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] COPY requirements.txt requirements.txt                           0.0s
#  => [4/7] RUN pip install -r requirements.txt                              0.2s
# [+] Building 3.1s (7/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 988B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8.10           2.5s
#  => [1/7] FROM docker.io/library/python:3.8.10@sha256:f7981c32c931f07d053  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 4.67kB                                        0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] COPY requirements.txt requirements.txt                           0.0s
#  => [4/7] RUN pip install -r requirements.txt                              0.4s
# [+] Building 3.2s (7/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 988B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8.10           2.5s
#  => [1/7] FROM docker.io/library/python:3.8.10@sha256:f7981c32c931f07d053  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 4.67kB                                        0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] COPY requirements.txt requirements.txt                           0.0s
#  => [4/7] RUN pip install -r requirements.txt                              0.5s
# [+] Building 3.4s (7/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 988B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8.10           2.5s
#  => [1/7] FROM docker.io/library/python:3.8.10@sha256:f7981c32c931f07d053  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 4.67kB                                        0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] COPY requirements.txt requirements.txt                           0.0s
#  => [4/7] RUN pip install -r requirements.txt                              0.7s
# [+] Building 3.5s (7/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 988B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8.10           2.5s
#  => [1/7] FROM docker.io/library/python:3.8.10@sha256:f7981c32c931f07d053  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 4.67kB                                        0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] COPY requirements.txt requirements.txt                           0.0s
#  => [4/7] RUN pip install -r requirements.txt                              0.8s
# [+] Building 3.7s (7/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 988B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8.10           2.5s
#  => [1/7] FROM docker.io/library/python:3.8.10@sha256:f7981c32c931f07d053  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 4.67kB                                        0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] COPY requirements.txt requirements.txt                           0.0s
#  => [4/7] RUN pip install -r requirements.txt                              1.0s
# [+] Building 3.8s (7/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 988B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8.10           2.5s
#  => [1/7] FROM docker.io/library/python:3.8.10@sha256:f7981c32c931f07d053  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 4.67kB                                        0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] COPY requirements.txt requirements.txt                           0.0s
#  => [4/7] RUN pip install -r requirements.txt                              1.1s
# [+] Building 4.0s (7/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 988B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8.10           2.5s
#  => [1/7] FROM docker.io/library/python:3.8.10@sha256:f7981c32c931f07d053  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 4.67kB                                        0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] COPY requirements.txt requirements.txt                           0.0s
#  => [4/7] RUN pip install -r requirements.txt                              1.3s
# [+] Building 4.1s (7/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 988B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8.10           2.5s
#  => [1/7] FROM docker.io/library/python:3.8.10@sha256:f7981c32c931f07d053  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 4.67kB                                        0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] COPY requirements.txt requirements.txt                           0.0s
#  => [4/7] RUN pip install -r requirements.txt                              1.4s
# [+] Building 4.3s (7/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 988B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8.10           2.5s
#  => [1/7] FROM docker.io/library/python:3.8.10@sha256:f7981c32c931f07d053  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 4.67kB                                        0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] COPY requirements.txt requirements.txt                           0.0s
#  => [4/7] RUN pip install -r requirements.txt                              1.6s
# [+] Building 4.4s (7/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 988B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8.10           2.5s
#  => [1/7] FROM docker.io/library/python:3.8.10@sha256:f7981c32c931f07d053  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 4.67kB                                        0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] COPY requirements.txt requirements.txt                           0.0s
#  => [4/7] RUN pip install -r requirements.txt                              1.7s
# [+] Building 4.6s (7/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 988B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8.10           2.5s
#  => [1/7] FROM docker.io/library/python:3.8.10@sha256:f7981c32c931f07d053  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 4.67kB                                        0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] COPY requirements.txt requirements.txt                           0.0s
#  => [4/7] RUN pip install -r requirements.txt                              1.9s
# [+] Building 4.7s (7/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 988B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8.10           2.5s
#  => [1/7] FROM docker.io/library/python:3.8.10@sha256:f7981c32c931f07d053  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 4.67kB                                        0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] COPY requirements.txt requirements.txt                           0.0s
#  => [4/7] RUN pip install -r requirements.txt                              2.1s
# [+] Building 4.9s (7/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 988B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8.10           2.5s
#  => [1/7] FROM docker.io/library/python:3.8.10@sha256:f7981c32c931f07d053  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 4.67kB                                        0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] COPY requirements.txt requirements.txt                           0.0s
#  => [4/7] RUN pip install -r requirements.txt                              2.2s
# [+] Building 5.0s (7/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 988B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8.10           2.5s
#  => [1/7] FROM docker.io/library/python:3.8.10@sha256:f7981c32c931f07d053  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 4.67kB                                        0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] COPY requirements.txt requirements.txt                           0.0s
#  => [4/7] RUN pip install -r requirements.txt                              2.4s
# [+] Building 5.2s (7/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 988B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8.10           2.5s
#  => [1/7] FROM docker.io/library/python:3.8.10@sha256:f7981c32c931f07d053  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 4.67kB                                        0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] COPY requirements.txt requirements.txt                           0.0s
#  => [4/7] RUN pip install -r requirements.txt                              2.5s
#  => => # Collecting pandas
# [+] Building 5.3s (7/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 988B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8.10           2.5s
#  => [1/7] FROM docker.io/library/python:3.8.10@sha256:f7981c32c931f07d053  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 4.67kB                                        0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] COPY requirements.txt requirements.txt                           0.0s
#  => [4/7] RUN pip install -r requirements.txt                              2.7s
#  => => # Collecting pandas
#  => => #   Downloading pandas-1.4.2-cp38-cp38-manylinux_2_17_x86_64.manylinux20
#  => => # 14_x86_64.whl (11.7 MB)
# [+] Building 5.5s (7/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 988B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8.10           2.5s
#  => [1/7] FROM docker.io/library/python:3.8.10@sha256:f7981c32c931f07d053  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 4.67kB                                        0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] COPY requirements.txt requirements.txt                           0.0s
#  => [4/7] RUN pip install -r requirements.txt                              2.8s
#  => => # Collecting pandas
#  => => #   Downloading pandas-1.4.2-cp38-cp38-manylinux_2_17_x86_64.manylinux20
#  => => # 14_x86_64.whl (11.7 MB)
# [+] Building 5.7s (7/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 988B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8.10           2.5s
#  => [1/7] FROM docker.io/library/python:3.8.10@sha256:f7981c32c931f07d053  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 4.67kB                                        0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] COPY requirements.txt requirements.txt                           0.0s
#  => [4/7] RUN pip install -r requirements.txt                              3.0s
#  => => # Collecting pandas
#  => => #   Downloading pandas-1.4.2-cp38-cp38-manylinux_2_17_x86_64.manylinux20
#  => => # 14_x86_64.whl (11.7 MB)
# [+] Building 5.8s (7/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 988B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8.10           2.5s
#  => [1/7] FROM docker.io/library/python:3.8.10@sha256:f7981c32c931f07d053  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 4.67kB                                        0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] COPY requirements.txt requirements.txt                           0.0s
#  => [4/7] RUN pip install -r requirements.txt                              3.1s
#  => => # Collecting pandas
#  => => #   Downloading pandas-1.4.2-cp38-cp38-manylinux_2_17_x86_64.manylinux20
#  => => # 14_x86_64.whl (11.7 MB)
# [+] Building 6.0s (7/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 988B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8.10           2.5s
#  => [1/7] FROM docker.io/library/python:3.8.10@sha256:f7981c32c931f07d053  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 4.67kB                                        0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] COPY requirements.txt requirements.txt                           0.0s
#  => [4/7] RUN pip install -r requirements.txt                              3.3s
#  => => # Collecting pandas
#  => => #   Downloading pandas-1.4.2-cp38-cp38-manylinux_2_17_x86_64.manylinux20
#  => => # 14_x86_64.whl (11.7 MB)
# [+] Building 6.1s (7/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 988B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8.10           2.5s
#  => [1/7] FROM docker.io/library/python:3.8.10@sha256:f7981c32c931f07d053  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 4.67kB                                        0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] COPY requirements.txt requirements.txt                           0.0s
#  => [4/7] RUN pip install -r requirements.txt                              3.4s
#  => => # Collecting pandas
#  => => #   Downloading pandas-1.4.2-cp38-cp38-manylinux_2_17_x86_64.manylinux20
#  => => # 14_x86_64.whl (11.7 MB)
# [+] Building 6.3s (7/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 988B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8.10           2.5s
#  => [1/7] FROM docker.io/library/python:3.8.10@sha256:f7981c32c931f07d053  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 4.67kB                                        0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] COPY requirements.txt requirements.txt                           0.0s
#  => [4/7] RUN pip install -r requirements.txt                              3.6s
#  => => # Collecting pandas
#  => => #   Downloading pandas-1.4.2-cp38-cp38-manylinux_2_17_x86_64.manylinux20
#  => => # 14_x86_64.whl (11.7 MB)
# [+] Building 6.4s (7/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 988B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8.10           2.5s
#  => [1/7] FROM docker.io/library/python:3.8.10@sha256:f7981c32c931f07d053  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 4.67kB                                        0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] COPY requirements.txt requirements.txt                           0.0s
#  => [4/7] RUN pip install -r requirements.txt                              3.7s
#  => => # Collecting pandas
#  => => #   Downloading pandas-1.4.2-cp38-cp38-manylinux_2_17_x86_64.manylinux20
#  => => # 14_x86_64.whl (11.7 MB)
# [+] Building 6.6s (7/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 988B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8.10           2.5s
#  => [1/7] FROM docker.io/library/python:3.8.10@sha256:f7981c32c931f07d053  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 4.67kB                                        0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] COPY requirements.txt requirements.txt                           0.0s
#  => [4/7] RUN pip install -r requirements.txt                              3.9s
#  => => # Collecting pandas
#  => => #   Downloading pandas-1.4.2-cp38-cp38-manylinux_2_17_x86_64.manylinux20
#  => => # 14_x86_64.whl (11.7 MB)
# [+] Building 6.7s (7/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 988B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8.10           2.5s
#  => [1/7] FROM docker.io/library/python:3.8.10@sha256:f7981c32c931f07d053  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 4.67kB                                        0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] COPY requirements.txt requirements.txt                           0.0s
#  => [4/7] RUN pip install -r requirements.txt                              4.0s
#  => => # Collecting pandas
#  => => #   Downloading pandas-1.4.2-cp38-cp38-manylinux_2_17_x86_64.manylinux20
#  => => # 14_x86_64.whl (11.7 MB)
# [+] Building 6.9s (7/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 988B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8.10           2.5s
#  => [1/7] FROM docker.io/library/python:3.8.10@sha256:f7981c32c931f07d053  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 4.67kB                                        0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] COPY requirements.txt requirements.txt                           0.0s
#  => [4/7] RUN pip install -r requirements.txt                              4.2s
#  => => # Collecting pandas
#  => => #   Downloading pandas-1.4.2-cp38-cp38-manylinux_2_17_x86_64.manylinux20
#  => => # 14_x86_64.whl (11.7 MB)
# [+] Building 7.0s (7/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 988B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8.10           2.5s
#  => [1/7] FROM docker.io/library/python:3.8.10@sha256:f7981c32c931f07d053  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 4.67kB                                        0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] COPY requirements.txt requirements.txt                           0.0s
#  => [4/7] RUN pip install -r requirements.txt                              4.3s
#  => => # Collecting pandas
#  => => #   Downloading pandas-1.4.2-cp38-cp38-manylinux_2_17_x86_64.manylinux20
#  => => # 14_x86_64.whl (11.7 MB)
# [+] Building 7.2s (7/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 988B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8.10           2.5s
#  => [1/7] FROM docker.io/library/python:3.8.10@sha256:f7981c32c931f07d053  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 4.67kB                                        0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] COPY requirements.txt requirements.txt                           0.0s
#  => [4/7] RUN pip install -r requirements.txt                              4.5s
#  => => # Collecting pandas
#  => => #   Downloading pandas-1.4.2-cp38-cp38-manylinux_2_17_x86_64.manylinux20
#  => => # 14_x86_64.whl (11.7 MB)
# [+] Building 7.3s (7/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 988B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8.10           2.5s
#  => [1/7] FROM docker.io/library/python:3.8.10@sha256:f7981c32c931f07d053  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 4.67kB                                        0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] COPY requirements.txt requirements.txt                           0.0s
#  => [4/7] RUN pip install -r requirements.txt                              4.6s
#  => => # Collecting pandas
#  => => #   Downloading pandas-1.4.2-cp38-cp38-manylinux_2_17_x86_64.manylinux20
#  => => # 14_x86_64.whl (11.7 MB)
# [+] Building 7.5s (7/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 988B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8.10           2.5s
#  => [1/7] FROM docker.io/library/python:3.8.10@sha256:f7981c32c931f07d053  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 4.67kB                                        0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] COPY requirements.txt requirements.txt                           0.0s
#  => [4/7] RUN pip install -r requirements.txt                              4.8s
#  => => # Collecting pandas
#  => => #   Downloading pandas-1.4.2-cp38-cp38-manylinux_2_17_x86_64.manylinux20
#  => => # 14_x86_64.whl (11.7 MB)
# [+] Building 7.6s (7/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 988B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8.10           2.5s
#  => [1/7] FROM docker.io/library/python:3.8.10@sha256:f7981c32c931f07d053  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 4.67kB                                        0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] COPY requirements.txt requirements.txt                           0.0s
#  => [4/7] RUN pip install -r requirements.txt                              4.9s
#  => => # Collecting pandas
#  => => #   Downloading pandas-1.4.2-cp38-cp38-manylinux_2_17_x86_64.manylinux20
#  => => # 14_x86_64.whl (11.7 MB)
# [+] Building 7.7s (7/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 988B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8.10           2.5s
#  => [1/7] FROM docker.io/library/python:3.8.10@sha256:f7981c32c931f07d053  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 4.67kB                                        0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] COPY requirements.txt requirements.txt                           0.0s
#  => [4/7] RUN pip install -r requirements.txt                              5.0s
#  => => # Collecting pandas
#  => => #   Downloading pandas-1.4.2-cp38-cp38-manylinux_2_17_x86_64.manylinux20
#  => => # 14_x86_64.whl (11.7 MB)
#  => => # Collecting werkzeug==2.0.3
# [+] Building 7.8s (7/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 988B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8.10           2.5s
#  => [1/7] FROM docker.io/library/python:3.8.10@sha256:f7981c32c931f07d053  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 4.67kB                                        0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] COPY requirements.txt requirements.txt                           0.0s
#  => [4/7] RUN pip install -r requirements.txt                              5.1s
#  => => # Collecting pandas
#  => => #   Downloading pandas-1.4.2-cp38-cp38-manylinux_2_17_x86_64.manylinux20
#  => => # 14_x86_64.whl (11.7 MB)
#  => => # Collecting werkzeug==2.0.3
#  => => #   Downloading Werkzeug-2.0.3-py3-none-any.whl (289 kB)
#  => => # Collecting jupyter
# [+] Building 8.0s (7/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 988B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8.10           2.5s
#  => [1/7] FROM docker.io/library/python:3.8.10@sha256:f7981c32c931f07d053  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 4.67kB                                        0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] COPY requirements.txt requirements.txt                           0.0s
# ...
#  => => transferring dockerfile: 988B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8.10           2.5s
#  => [1/7] FROM docker.io/library/python:3.8.10@sha256:f7981c32c931f07d053  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 4.67kB                                        0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] COPY requirements.txt requirements.txt                           0.0s
#  => [4/7] RUN pip install -r requirements.txt                             38.0s
#  => => # aging, nbclient, mistune, jupyterlab-pygments, Jinja2, ipython, defuse
#  => => # dxml, debugpy, bleach, beautifulsoup4, argon2-cffi-bindings, terminado
#  => => # , Send2Trash, prometheus-client, nbconvert, ipython-genutils, ipykerne
#  => => # l, argon2-cffi, notebook, widgetsnbextension, qtpy, jupyterlab-widgets
#  => => # , werkzeug, qtconsole, pytz, numpy, jupyter-console, itsdangerous, ipy
#  => => # widgets, importlib-metadata, click, pandas, jupyter, Flask
# [+] Building 40.8s (7/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 988B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8.10           2.5s
#  => [1/7] FROM docker.io/library/python:3.8.10@sha256:f7981c32c931f07d053  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 4.67kB                                        0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] COPY requirements.txt requirements.txt                           0.0s
#  => [4/7] RUN pip install -r requirements.txt                             38.1s
#  => => # s-5.2.2.post1 wcwidth-0.2.5 webencodings-0.5.1 werkzeug-2.0.3 widgetsn
#  => => # bextension-3.6.0 zipp-3.8.0
#  => => # WARNING: Running pip as the 'root' user can result in broken permissio
#  => => # ns and conflicting behaviour with the system package manager. It is re
#  => => # commended to use a virtual environment instead: https://pip.pypa.io/wa
#  => => # rnings/venv
# [+] Building 41.0s (7/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 988B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8.10           2.5s
#  => [1/7] FROM docker.io/library/python:3.8.10@sha256:f7981c32c931f07d053  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 4.67kB                                        0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] COPY requirements.txt requirements.txt                           0.0s
#  => [4/7] RUN pip install -r requirements.txt                             38.3s
#  => => # commended to use a virtual environment instead: https://pip.pypa.io/wa
#  => => # rnings/venv
#  => => # WARNING: You are using pip version 21.1.3; however, version 22.1.2 is
#  => => # available.
#  => => # You should consider upgrading via the '/usr/local/bin/python -m pip in
#  => => # stall --upgrade pip' command.
# [+] Building 41.1s (7/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 988B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8.10           2.5s
#  => [1/7] FROM docker.io/library/python:3.8.10@sha256:f7981c32c931f07d053  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 4.67kB                                        0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] COPY requirements.txt requirements.txt                           0.0s
#  => [4/7] RUN pip install -r requirements.txt                             38.4s
#  => => # commended to use a virtual environment instead: https://pip.pypa.io/wa
#  => => # rnings/venv
#  => => # WARNING: You are using pip version 21.1.3; however, version 22.1.2 is
#  => => # available.
#  => => # You should consider upgrading via the '/usr/local/bin/python -m pip in
#  => => # stall --upgrade pip' command.
# [+] Building 41.3s (7/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 988B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8.10           2.5s
#  => [1/7] FROM docker.io/library/python:3.8.10@sha256:f7981c32c931f07d053  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 4.67kB                                        0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] COPY requirements.txt requirements.txt                           0.0s
#  => [4/7] RUN pip install -r requirements.txt                             38.6s
#  => => # commended to use a virtual environment instead: https://pip.pypa.io/wa
#  => => # rnings/venv
#  => => # WARNING: You are using pip version 21.1.3; however, version 22.1.2 is
#  => => # available.
#  => => # You should consider upgrading via the '/usr/local/bin/python -m pip in
#  => => # stall --upgrade pip' command.
# [+] Building 41.4s (7/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 988B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8.10           2.5s
#  => [1/7] FROM docker.io/library/python:3.8.10@sha256:f7981c32c931f07d053  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 4.67kB                                        0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] COPY requirements.txt requirements.txt                           0.0s
#  => [4/7] RUN pip install -r requirements.txt                             38.7s
#  => => # commended to use a virtual environment instead: https://pip.pypa.io/wa
#  => => # rnings/venv
#  => => # WARNING: You are using pip version 21.1.3; however, version 22.1.2 is
#  => => # available.
#  => => # You should consider upgrading via the '/usr/local/bin/python -m pip in
#  => => # stall --upgrade pip' command.
# [+] Building 41.6s (7/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 988B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8.10           2.5s
#  => [1/7] FROM docker.io/library/python:3.8.10@sha256:f7981c32c931f07d053  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 4.67kB                                        0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] COPY requirements.txt requirements.txt                           0.0s
#  => [4/7] RUN pip install -r requirements.txt                             38.9s
#  => => # commended to use a virtual environment instead: https://pip.pypa.io/wa
#  => => # rnings/venv
#  => => # WARNING: You are using pip version 21.1.3; however, version 22.1.2 is
#  => => # available.
#  => => # You should consider upgrading via the '/usr/local/bin/python -m pip in
#  => => # stall --upgrade pip' command.
# [+] Building 41.7s (7/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 988B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8.10           2.5s
#  => [1/7] FROM docker.io/library/python:3.8.10@sha256:f7981c32c931f07d053  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 4.67kB                                        0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] COPY requirements.txt requirements.txt                           0.0s
#  => [4/7] RUN pip install -r requirements.txt                             39.0s
#  => => # commended to use a virtual environment instead: https://pip.pypa.io/wa
#  => => # rnings/venv
#  => => # WARNING: You are using pip version 21.1.3; however, version 22.1.2 is
#  => => # available.
#  => => # You should consider upgrading via the '/usr/local/bin/python -m pip in
#  => => # stall --upgrade pip' command.
# [+] Building 41.9s (8/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 988B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8.10           2.5s
#  => [1/7] FROM docker.io/library/python:3.8.10@sha256:f7981c32c931f07d053  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 4.67kB                                        0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] COPY requirements.txt requirements.txt                           0.0s
#  => [4/7] RUN pip install -r requirements.txt                             39.1s
#  => [5/7] RUN python -m spacy download en_core_web_sm                      0.1s
#
#
#
#
#
# [+] Building 42.0s (8/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 988B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8.10           2.5s
#  => [1/7] FROM docker.io/library/python:3.8.10@sha256:f7981c32c931f07d053  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 4.67kB                                        0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] COPY requirements.txt requirements.txt                           0.0s
#  => [4/7] RUN pip install -r requirements.txt                             39.1s
#  => [5/7] RUN python -m spacy download en_core_web_sm                      0.2s
# [+] Building 42.1s (9/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 988B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8.10           2.5s
#  => [1/7] FROM docker.io/library/python:3.8.10@sha256:f7981c32c931f07d053  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 4.67kB                                        0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] COPY requirements.txt requirements.txt                           0.0s
#  => [4/7] RUN pip install -r requirements.txt                             39.1s
#  => ERROR [5/7] RUN python -m spacy download en_core_web_sm                0.3s
# ------
#  > [5/7] RUN python -m spacy download en_core_web_sm:
# #9 0.321 /usr/local/bin/python: No module named spacy
# ------
# executor failed running [/bin/sh -c python -m spacy download en_core_web_sm]: exit code: 1
#  * Serving Flask app 'app.py' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
# /usr/local/lib/python3.8/site-packages/sklearn/base.py:329: UserWarning: Trying to unpickle estimator LinearRegression from version 1.0.2 when using version 1.1.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# 2022-06-10 16:29:15,087 - [_internal.py:225] - WARNING -  * Running on all addresses.
#    WARNING: This is a development server. Do not use it in a production deployment.
# 2022-06-10 16:29:15,087 - [_internal.py:225] - INFO -  * Running on http://172.17.0.2:5000/ (Press CTRL+C to quit)
# ^C

# %%
# Send request

# %%
# !cd 5_kubernetes
# !minikube start
# !minikube image load hello-ml
# !kubectl apply -f deployment.yaml
